# %%
""" Path to project /Users/a.ovsiannikova/PycharmProjects/HIV_immunogenicity"""
# Out:
# ' Path to project /Users/a.ovsiannikova/PycharmProjects/HIV_immunogenicity'

# %%
# %matplotlib inline
from util.aa_properties import *
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from pandas.plotting import scatter_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# "TCR contact residue hydrophobicity is a hallmark of immunogenic CD8+ T cell epitopes" dataset
# TODO: link here

dataset = pd.read_csv('data/pnas_dataset.csv', sep=';')

# %%
# some of the columns are read with leading space - replacing column names

dataset.columns = ['Epitope', 'Epitope Start', 'Epitope End', 'MHC Allele',
       'Epitope Source Organism Name', 'Length', 'Immunogenicity']

# %%
# function for mice filtering from the dataset

def filter_mice(seq):
    return 'Human' if seq.startswith('HLA') else 'Mouse'

# %%
# creating Host column - 'Human' or 'Mouse'

dataset['Host'] = dataset['MHC Allele'].apply(filter_mice)

# %%
# keeping only Human hosts

dataset = dataset.loc[dataset.Host == 'Human']

# %%
# adding amino acid score (sum)
dataset['aa_score'] = 0
dataset['aa_score'] = dataset.Epitope.apply(aaprop_sequence)

# adding kidera score (sum)
dataset['kidera_score'] = 0
dataset['kidera_score'] = dataset.Epitope.apply(score_sequence)

# adding hydrophobicity score (sum)
dataset['hydrophobicity_score'] = 0
dataset['hydrophobicity_score'] = dataset.Epitope.apply(score_hydrophobicity_sequence)

# %%
# function to score epitopes by all available amino acid parameters

def score_acids(ds):
    # for each column in amino acid data 
    for column in aa_properties.columns:
        
        # adding sum of column
        ds[column] = ds.apply(lambda x: aa_properties[column].loc[list(x.Epitope)].sum(), axis=1)
    return ds

# %%
# separate amino acid score

dataset = score_acids(dataset)

# %%
dataset.head(25)
# Out:
#         Epitope  Epitope Start  Epitope End   MHC Allele  \
# 0     KLEDLERDL             26           34  HLA-A*02:01
# 1     DLMGYIPLV            132          140  HLA-A*02:01
# 2   QTVTSTPVQGR            792          802  HLA-A*68:01
# 3   TTVYPPSSTAK            945          955  HLA-A*03:01
# 4     LITGRLQSL            978          986       HLA-A2
# 7     AVAKAGKPL            239          247  HLA-E*01:01
# 8     AMLQDIATL            287          295  HLA-E*01:01
# 9     KMLRGVNVL             15           23  HLA-E*01:01
# 10    KLQERVAKL            364          372  HLA-E*01:01
# 11  ITKKVADLVGF            102          112  HLA-B*57:02
# 12   AEWPTFNVGW             41           50  HLA-B*44:03
# 13    SRHHAFCFR            666          674      HLA-B27
# 14    ATLGFGAYM           1260         1268  HLA-A*02:01
# 15   LIYDSSLCDL             83           92       HLA-A2
# 16   YLLPRRGPRL             35           44       HLA-A2
# 17   LLALLSCLTV            178          187       HLA-A2
# 18   KLVALGINAV           1406         1415       HLA-A2
# 19    GLIEKNIEL            425          433       HLA-A2
# 20  FLFDGSPTYVL           2335         2345  HLA-A*02:01
# 21   FLPSDFFPSV             18           27       HLA-A2
# 22    FVFLRNFSL             27           35  HLA-A*02:01
# 23   FPPSPLFFFL              4           13  HLA-A*02:01
# 25    CMTWNQMNL            235          243  HLA-A*24:02
# 27    GLIQLVEGV              4           12  HLA-A*02:01
# 28   NIKMHCEFHA             29           38  HLA-A*02:01
#
#             Epitope Source Organism Name  Length Immunogenicity   Host  \
# 0           Hepatitis delta virus TW2667       9       Positive  Human
# 1           Hepatitis C virus subtype 1a       9       Positive  Human
# 2                    Human herpesvirus 5      11       Positive  Human
# 3                    Human herpesvirus 5      11       Positive  Human
# 4                       SARS coronavirus       9       Positive  Human
# 7                 Salmonella typhi Ty21a       9       Positive  Human
# 8                 Salmonella typhi Ty21a       9       Positive  Human
# 9                 Salmonella typhi Ty21a       9       Positive  Human
# 10                Salmonella typhi Ty21a       9       Positive  Human
# 11                          Homo sapiens      11       Positive  Human
# 12          Friend murine leukemia virus      10       Positive  Human
# 13                          Homo sapiens       9       Positive  Human
# 14  Hepatitis C virus (isolate Japanese)       9       Positive  Human
# 15                          Homo sapiens      10       Positive  Human
# 16          Hepatitis C virus subtype 1b      10       Positive  Human
# 17          Hepatitis C virus subtype 1b      10       Positive  Human
# 18          Hepatitis C virus subtype 1b      10       Positive  Human
# 19                          Homo sapiens       9       Positive  Human
# 20                          Homo sapiens      11       Positive  Human
# 21                     Hepatitis B virus      10       Positive  Human
# 22                          Homo sapiens       9       Positive  Human
# 23                          Homo sapiens      10       Positive  Human
# 25                          Homo sapiens       9       Positive  Human
# 27                          Homo sapiens       9       Positive  Human
# 28                          Homo sapiens      10       Positive  Human
#
#     aa_score  kidera_score  ...   kf1   kf2   kf3   kf4   kf5   kf6   kf7  \
# 0      11.05         -4.98  ... -4.98  2.03 -5.96  4.23 -6.27 -6.21  1.99
# 1       8.79          0.53  ...  0.53 -1.72  0.77 -4.76  0.92 -4.45  0.07
# 2       9.68          2.91  ...  2.91 -5.14  8.00  4.67  1.97 -0.34  0.91
# 3       9.29          5.26  ...  5.26 -5.00  3.29  1.70  2.15 -5.02 -2.89
# 4       9.30         -1.57  ... -1.57 -2.39  3.65 -0.21 -3.00 -5.40  3.48
# 7       9.62         -3.62  ... -3.62 -6.37 -2.95  0.18  1.22 -9.00  3.21
# 8      10.75         -6.96  ... -6.96 -4.00 -1.35 -1.70 -1.42 -3.16  0.51
# 9       9.54         -2.48  ... -2.48 -1.18  3.97  0.49  2.02 -5.10  3.34
# 10     10.93         -6.76  ... -6.76  0.96 -0.04  4.67 -0.36 -7.48  4.75
# 11     11.33         -3.40  ... -3.40 -3.51  3.24  0.31  1.36 -8.22  0.80
# 12      9.49          1.56  ...  1.56 -0.07 -2.63 -3.54 -2.78 -0.84  0.25
# 13      9.72         -1.43  ... -1.43  1.90  1.10  0.54 -1.59  2.52 -1.09
# 14      9.08         -1.21  ... -1.21 -5.32 -1.41 -4.05 -0.09 -3.59  4.06
# 15     10.42          0.43  ...  0.43 -2.17 -0.52 -3.22 -5.16 -4.95 -3.56
# 16      9.10          4.50  ...  4.50  2.67  1.66  0.09 -4.89 -6.46  7.25
# 17     11.45         -6.31  ... -6.31 -5.05  1.69 -6.17 -4.20 -9.65  3.40
# 18     10.66         -5.15  ... -5.15 -6.13  2.87 -1.96 -0.68 -8.61  0.93
# 19     10.11         -4.18  ... -4.18 -1.15 -0.70  0.95 -2.98 -4.60  2.72
# 20     10.13          3.31  ...  3.31 -1.56  0.05 -5.07 -0.41 -7.84  0.33
# 21      9.14          3.91  ...  3.91 -0.81 -2.84 -5.64  1.03 -6.90 -2.80
# 22      9.40         -1.28  ... -1.28  2.35  1.89 -3.79 -1.67 -6.94  1.80
# 23      9.26          4.07  ...  4.07  1.85 -5.21 -9.75  2.21 -9.12  3.61
# 25     10.23         -1.35  ... -1.35  0.97 -0.31 -1.83  2.94  5.51  3.42
# 27      9.22         -3.29  ... -3.29 -5.07  3.39 -1.82 -0.65 -4.92  2.47
# 28     11.92         -5.25  ... -5.25  0.42 -2.03 -0.01  3.67  3.54 -1.18
#
#              kf8   kf9  kf10
# 0  -1.050000e+00  1.92  5.48
# 1   7.200000e-01 -0.38  2.41
# 2  -6.230000e+00 -4.32 -1.91
# 3  -9.420000e+00 -2.92  0.85
# 4  -2.810000e+00 -0.98  0.03
# 7  -1.040000e+00 -1.26  1.52
# 8  -2.450000e+00  0.88 -2.05
# 9   1.830000e+00 -2.10  3.69
# 10 -2.420000e+00 -0.46  1.71
# 11  2.410000e+00 -0.31  2.08
# 12  8.000000e-01 -3.87 -2.95
# 13  4.400000e-01  6.51  4.63
# 14  4.890000e+00 -2.62  1.44
# 15 -2.790000e+00  2.67  3.58
# 16 -4.660000e+00  1.81  6.01
# 17 -6.810000e+00  1.60  5.88
# 18  2.460000e+00  0.02 -0.25
# 19  3.770000e+00  0.48 -2.61
# 20  4.440892e-16  2.12  3.00
# 21 -3.830000e+00  5.42 -0.06
# 22  1.530000e+00  5.93  0.16
# 23 -5.170000e+00  8.99 -0.97
# 25 -1.030000e+00 -1.65 -3.63
# 27  3.500000e+00 -3.06 -0.15
# 28  3.420000e+00  4.97  0.68
#
# [25 rows x 36 columns]

# %%
# check if there are duplicate epitopes
# TODO: there are, all kept - will change soon

nonunique = dataset.groupby('Epitope').size().loc[dataset.groupby('Epitope').size() >= 2].index

# %%
# duplicate epitopes data

dataset.loc[dataset.Epitope.isin(nonunique)].sort_values('Epitope')
# Out:
#           Epitope  Epitope Start  Epitope End   MHC Allele  \
# 112     ALSDHHIYL            216          224  HLA-A*02:01
# 5733    ALSDHHIYL            216          224       HLA-A2
# 20    FLFDGSPTYVL           2335         2345  HLA-A*02:01
# 5705  FLFDGSPTYVL           2335         2345       HLA-A2
# 2594   GIVEQCCTSI             90           99  HLA-A*02:01
# 5990   GIVEQCCTSI             90           99  HLA-A*02:01
# 107     GLLGTLVQL            400          408  HLA-A*02:01
# 5321    GLLGTLVQL            400          408       HLA-A2
# 110     SLFPGKLEV           1010         1018  HLA-A*02:01
# 6610    SLFPGKLEV           1010         1018       HLA-A2
# 109     SLSEKTVLL            106          114  HLA-A*02:01
# 5331    SLSEKTVLL            106          114       HLA-A2
# 108     SLWGQPAEA             18           26  HLA-A*02:01
# 5426    SLWGQPAEA             18           26       HLA-A2
#
#      Epitope Source Organism Name  Length Immunogenicity   Host  aa_score  \
# 112                  Homo sapiens       9       Positive  Human      9.88
# 5733                 Homo sapiens       9       Negative  Human      9.88
# 20                   Homo sapiens      11       Positive  Human     10.13
# 5705                 Homo sapiens      11       Negative  Human     10.13
# 2594                 Homo sapiens      10       Positive  Human      9.98
# 5990                 Homo sapiens      10       Negative  Human      9.98
# 107                  Homo sapiens       9       Positive  Human      9.32
# 5321                 Homo sapiens       9       Negative  Human      9.32
# 110                  Homo sapiens       9       Positive  Human      9.15
# 6610                 Homo sapiens       9       Negative  Human      9.15
# 109                  Homo sapiens       9       Positive  Human      9.94
# 5331                 Homo sapiens       9       Negative  Human      9.94
# 108                  Homo sapiens       9       Positive  Human      9.48
# 5426                 Homo sapiens       9       Negative  Human      9.48
#
#       kidera_score  ...   kf1   kf2   kf3   kf4   kf5   kf6   kf7  \
# 112          -2.42  ... -2.42 -0.61 -0.84 -2.01 -0.48 -3.79 -6.53
# 5733         -2.42  ... -2.42 -0.61 -0.84 -2.01 -0.48 -3.79 -6.53
# 20            3.31  ...  3.31 -1.56  0.05 -5.07 -0.41 -7.84  0.33
# 5705          3.31  ...  3.31 -1.56  0.05 -5.07 -0.41 -7.84  0.33
# 2594         -1.35  ... -1.35 -6.12  6.12 -0.88 -2.42  4.73  0.86
# 5990         -1.35  ... -1.35 -6.12  6.12 -0.88 -2.42  4.73  0.86
# 107          -2.19  ... -2.19 -5.09  1.90 -3.39 -0.50 -8.43  6.49
# 5321         -2.19  ... -2.19 -5.09  1.90 -3.39 -0.50 -8.43  6.49
# 110          -0.49  ... -0.49 -2.09 -1.86 -1.65  0.62 -7.93  2.44
# 6610         -0.49  ... -0.49 -2.09 -1.86 -1.65  0.62 -7.93  2.44
# 109          -3.77  ... -3.77 -2.56  1.01  0.64 -1.44 -8.83 -0.54
# 5331         -3.77  ... -3.77 -2.56  1.01  0.64 -1.44 -8.83 -0.54
# 108          -1.45  ... -1.45 -4.18 -5.66 -1.43 -3.01 -3.04  0.69
# 5426         -1.45  ... -1.45 -4.18 -5.66 -1.43 -3.01 -3.04  0.69
#
#                kf8   kf9  kf10
# 112   2.000000e-01  3.77  3.86
# 5733  2.000000e-01  3.77  3.86
# 20    4.440892e-16  2.12  3.00
# 5705  4.440892e-16  2.12  3.00
# 2594 -5.700000e-01 -0.45 -2.74
# 5990 -5.700000e-01 -0.45 -2.74
# 107  -1.200000e-01 -2.57  3.15
# 5321 -1.200000e-01 -2.57  3.15
# 110  -1.150000e+00 -0.57  2.50
# 6610 -1.150000e+00 -0.57  2.50
# 109  -5.370000e+00 -2.44  3.65
# 5331 -5.370000e+00 -2.44  3.65
# 108  -2.740000e+00 -3.70 -3.13
# 5426 -2.740000e+00 -3.70 -3.13
#
# [14 rows x 36 columns]

# %%
# is this ok?

dataset.loc[dataset['Epitope Source Organism Name'] == 'Mus musculus']
# Out:
#           Epitope  Epitope Start  Epitope End   MHC Allele  \
# 1570    LLGRDSFEV            261          269  HLA-A*02:01
# 2788  RLFGIDLLWSV            226          236  HLA-A*02:01
# 2789   LFGIDLLWSV            227          236  HLA-A*02:01
# 2790    FGIDLLWSV            228          236  HLA-A*02:01
# 3082    LLVHFLPLL              3           11  HLA-A*02:01
# 3083   HLCGPHLVEA             29           38  HLA-A*02:01
# 3084    IVDQCCTSI             89           97  HLA-A*02:01
# 3086    ALWEPKPTQ             15           23  HLA-A*02:01
# 4791    AINSEMFLR            272          280  HLA-A*11:01
# 4792   TLALEVAQQK             79           88  HLA-A*11:01
# 4793   TLALEVARQK             77           86  HLA-A*11:01
# 4794   LALEVARQKR             78           87  HLA-A*11:01
# 4795   SPGDLQTLAL             71           80  HLA-B*07:02
# 6774    AETPDIKLF             12           20  HLA-B*44:02
#
#      Epitope Source Organism Name  Length Immunogenicity   Host  aa_score  \
# 1570                 Mus musculus       9       Positive  Human      9.40
# 2788                 Mus musculus      11       Positive  Human     11.22
# 2789                 Mus musculus      10       Positive  Human     10.26
# 2790                 Mus musculus       9       Positive  Human      8.96
# 3082                 Mus musculus       9       Positive  Human     10.22
# 3083                 Mus musculus      10       Positive  Human     10.87
# 3084                 Mus musculus       9       Positive  Human      9.02
# 3086                 Mus musculus       9       Positive  Human      9.38
# 4791                 Mus musculus       9       Positive  Human     10.22
# 4792                 Mus musculus      10       Positive  Human     12.12
# 4793                 Mus musculus      10       Positive  Human     11.81
# 4794                 Mus musculus      10       Positive  Human     11.95
# 4795                 Mus musculus      10       Positive  Human     10.22
# 6774                 Mus musculus       9       Negative  Human      9.68
#
#       kidera_score  ...   kf1   kf2   kf3   kf4   kf5    kf6   kf7   kf8  \
# 1570         -1.41  ... -1.41 -1.53 -0.69  0.08 -4.42  -5.25  0.39  1.31
# 2788         -1.43  ... -1.43  0.22  1.75 -4.53 -5.36  -7.10  0.00  0.28
# 2789         -1.65  ... -1.65 -1.05  0.38 -6.40 -3.66  -7.56 -0.92  0.67
# 2790         -0.61  ... -0.61 -1.05  0.62 -5.30 -3.11  -5.51 -1.88  1.43
# 3082         -4.50  ... -4.50  0.46 -0.95 -7.80  0.46 -11.31  2.85 -4.47
# 3083         -3.01  ... -3.01 -4.33 -2.51 -3.10  0.65  -1.42  0.13 -0.85
# 3084         -0.78  ... -0.78 -4.57  6.38 -1.08 -2.13   4.59 -2.02 -2.84
# 3086         -0.18  ... -0.18  0.32 -4.79  0.16  0.35  -3.58  3.15 -7.40
# 4791         -4.22  ... -4.22 -0.36 -0.40 -0.03 -2.84  -1.29 -0.16  0.95
# 4792         -8.41  ... -8.41 -3.26 -0.87  2.56 -0.13  -6.30  3.56 -3.89
# 4793         -7.72  ... -7.72 -2.23  0.43  3.33 -2.93  -6.43  3.64 -3.57
# 4794         -7.76  ... -7.76 -0.26  0.59  4.57 -4.53  -6.18  4.32 -2.81
# 4795          0.02  ...  0.02 -5.72 -3.21 -1.52 -1.73  -6.97  1.97 -4.84
# 6774         -2.43  ... -2.43 -1.09 -3.14 -0.01 -1.71  -4.92  0.81 -1.91
#
#        kf9  kf10
# 1570  0.16  3.81
# 2788 -0.68  2.48
# 2789 -0.91  1.55
# 2790 -1.36  0.62
# 3082  5.37  6.21
# 3083  2.77  6.45
# 3084  2.32 -2.38
# 3086 -1.58 -2.37
# 4791  1.77 -2.65
# 4792 -0.59 -2.44
# 4793 -0.33  0.82
# 4794  0.46  1.56
# 4795 -0.16  0.82
# 6774  3.14 -0.68
#
# [14 rows x 36 columns]

# %%
# self immunogenicity?

dataset.loc[(dataset['Epitope Source Organism Name'] == 'Homo sapiens') & (dataset.Immunogenicity == 'Positive')]
# Out:
#           Epitope  Epitope Start  Epitope End   MHC Allele  \
# 11    ITKKVADLVGF            102          112  HLA-B*57:02
# 13      SRHHAFCFR            666          674      HLA-B27
# 15     LIYDSSLCDL             83           92       HLA-A2
# 19      GLIEKNIEL            425          433       HLA-A2
# 20    FLFDGSPTYVL           2335         2345  HLA-A*02:01
# ...           ...            ...          ...          ...
# 4911    LLIDLTSFL            107          115  HLA-A*02:01
# 4912    LLSLFSLWL            115          123  HLA-A*02:01
# 4913    LLSILCIWV            145          153  HLA-A*02:01
# 4918    QLLNSVLTL            248          256  HLA-A*02:01
# 5034    HSWITRSEA            732          740  HLA-A*02:05
#
#      Epitope Source Organism Name  Length Immunogenicity   Host  aa_score  \
# 11                   Homo sapiens      11       Positive  Human     11.33
# 13                   Homo sapiens       9       Positive  Human      9.72
# 15                   Homo sapiens      10       Positive  Human     10.42
# 19                   Homo sapiens       9       Positive  Human     10.11
# 20                   Homo sapiens      11       Positive  Human     10.13
# ...                           ...     ...            ...    ...       ...
# 4911                 Homo sapiens       9       Positive  Human      9.92
# 4912                 Homo sapiens       9       Positive  Human     10.20
# 4913                 Homo sapiens       9       Positive  Human      9.67
# 4918                 Homo sapiens       9       Positive  Human      9.92
# 5034                 Homo sapiens       9       Positive  Human      9.33
#
#       kidera_score  ...   kf1   kf2   kf3   kf4   kf5    kf6   kf7  \
# 11           -3.40  ... -3.40 -3.51  3.24  0.31  1.36  -8.22  0.80
# 13           -1.43  ... -1.43  1.90  1.10  0.54 -1.59   2.52 -1.09
# 15            0.43  ...  0.43 -2.17 -0.52 -3.22 -5.16  -4.95 -3.56
# 19           -4.18  ... -4.18 -1.15 -0.70  0.95 -2.98  -4.60  2.72
# 20            3.31  ...  3.31 -1.56  0.05 -5.07 -0.41  -7.84  0.33
# ...            ...  ...   ...   ...   ...   ...   ...    ...   ...
# 4911         -3.45  ... -3.45 -1.18  0.26 -4.74 -3.75  -9.05  0.51
# 4912         -3.49  ... -3.49  0.92 -1.96 -7.66 -4.11 -11.35  1.21
# 4913         -4.09  ... -4.09 -0.90  4.79 -7.44 -4.31  -4.35 -0.70
# 4918         -3.16  ... -3.16 -2.32  2.40 -1.84 -0.73  -8.27  1.87
# 5034         -1.75  ... -1.75 -0.61  1.11  2.18 -4.55   1.04 -5.94
#
#                kf8   kf9  kf10
# 11    2.410000e+00 -0.31  2.08
# 13    4.400000e-01  6.51  4.63
# 15   -2.790000e+00  2.67  3.58
# 19    3.770000e+00  0.48 -2.61
# 20    4.440892e-16  2.12  3.00
# ...            ...   ...   ...
# 4911 -3.260000e+00  3.40  2.16
# 4912 -5.400000e+00 -0.28  3.15
# 4913 -3.440000e+00  0.07  0.15
# 4918 -4.760000e+00  0.88  0.27
# 5034 -2.960000e+00 -2.92 -0.69
#
# [516 rows x 36 columns]

# %%
# collecting unique alleles 
# TODO: need to use unique()

alleles = dataset.groupby('MHC Allele').size().index

# %%
# keeping only 6 first symbols from MHC Allelle (should be: HLA-S*XX:XX)
# TODO: 'HLA-A23' 'HLA-Cw6' 'HLA-E*01033 HLA-Class I, allele undetermined' 'HLA-B*44:27 (HLA-B*4427)' 'HLA-A3/11' etc

alleles_tmp = {allele: allele[:6] for allele in alleles}

# %%
set(alleles_tmp.values())
# Out:
# {'HLA-A*',
#  'HLA-A1',
#  'HLA-A2',
#  'HLA-A3',
#  'HLA-A6',
#  'HLA-B*',
#  'HLA-B1',
#  'HLA-B2',
#  'HLA-B3',
#  'HLA-B4',
#  'HLA-B5',
#  'HLA-B6',
#  'HLA-B7',
#  'HLA-B8',
#  'HLA-C*',
#  'HLA-Cl',
#  'HLA-Cw',
#  'HLA-E',
#  'HLA-E*'}

# %%
# encoder for alleles to get ints

le = LabelEncoder()
le.fit(list(set(alleles_tmp.values())))

# first, mapping alleles to their short versions
dataset['allele'] = dataset['MHC Allele'].map(alleles_tmp)

# encoding short names
dataset['Allele'] = le.transform(dataset['allele'])

# %%
# encoder for organisms
# TODO: group organisms?

le_organisms = LabelEncoder()
le_organisms.fit(dataset['Epitope Source Organism Name'])
dataset['Organism'] = le_organisms.transform(dataset['Epitope Source Organism Name'])

# %%
# target encoding 

encode_target = {'Positive': 1, 'Negative': 0}
dataset['target'] = dataset.Immunogenicity.map(encode_target)

# %%
# seems like organism column is split too much - a lot of unique organisms

dataset.groupby(['Epitope Source Organism Name']).size().to_frame().sort_values('Epitope Source Organism Name').head(30)
# Out:
#                                                     0
# Epitope Source Organism Name
# Adenoviridae                                        1
# Alcaligenes sp.                                     1
# Andes virus                                         3
# Aspergillus fumigatus                               3
# BK polyomavirus                                    37
# Brucella abortus                                    1
# Chlamydia pneumoniae                                3
# Chlamydia trachomatis                              18
# Chlamydophila pneumoniae CWL029                    23
# Coxsackievirus B4 (strain E2)                       1
# Dengue virus                                      355
# Dengue virus 1                                     20
# Dengue virus 1 Singapore/S275/1990                  1
# Dengue virus 2                                     49
# Dengue virus 2 D2/SG/05K4155DK1/2005                1
# Dengue virus 2 Thailand/16681/84                    3
# Dengue virus 2 Thailand/NGS-C/1944                  3
# Dengue virus 3                                     17
# Dengue virus 4                                     12
# Dengue virus 4 Dominica/814669/1981                 1
# Dengue virus 4 Thailand/0348/1991                   1
# Dengue virus type 1 Hawaii                          1
# Dengue virus type 3 CH53489                         1
# Dermatophagoides pteronyssinus                      3
# Ebola virus - Mayinga, Zaire, 1976                  3
# Francisella tularensis subsp. tularensis SCHU S4   17
# Friend murine leukemia virus                        2
# Giardia intestinalis                                1
# Guanarito virus                                     1
# H1N1 subtype                                        3

# %%
# keeping only numeric columns

df_train = dataset[['Epitope Start', 'Organism', 'Length', 'aa_score', 'kidera_score', 'hydrophobicity_score', 
                    'alpha', 'beta', 'charge', 'core', 'hydropathy', 'pH', 'polarity', 'rim', 'surface',
                    'turn', 'volume', 'count', 'strength', 'disorder', 'mjenergy', 'kf1',
                    'kf2', 'kf3', 'kf4', 'kf5', 'kf6', 'kf7', 'kf8', 'kf9', 'kf10',
                    'target', 'Allele']]

# %%
# making train - test split with stratification by target value and shuffling
# TODO: set random state?

X_train, X_test, y_train, y_test = train_test_split(df_train.drop('target', axis=1), df_train.target, test_size=0.3, 
                                                    stratify=df_train.target, shuffle=True)

# %%
# scaling features. scaler is fitted on train data to prevent data leak

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)

# %%
# random forest to try
# TODO: boolean true?
# no need in test set actually as oob scoring can be performed

forest = RandomForestClassifier(n_estimators = 350, max_depth = 15, max_features = 'sqrt', 
                                bootstrap='True', n_jobs = -1, oob_score=True, min_samples_leaf=5, 
                                min_samples_split=5, random_state=6)

# %%
# fitting with train data

forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap='True', class_weight=None, criterion='gini',
#                        max_depth=15, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=350,
#                        n_jobs=-1, oob_score=True, random_state=6, verbose=0,
#                        warm_start=False)

# %%
# too lazy to check on test
# TODO: one day...

forest.oob_score_
# Out:
# 0.9479932165065008

# %%
# feature importance can indicate if there is any kind of overfitting
# seems there is: feature[1] and feature[-1] have large weights

forest.feature_importances_
# Out:
# array([0.03989642, 0.42854519, 0.0035122 , 0.00771969, 0.00798827,
#        0.0280763 , 0.00846064, 0.01023462, 0.00449255, 0.00872937,
#        0.03514005, 0.00680682, 0.02733456, 0.02170409, 0.01254793,
#        0.00944392, 0.00797167, 0.00344516, 0.02449113, 0.00802568,
#        0.01900346, 0.00842427, 0.00834821, 0.00860247, 0.06705372,
#        0.009455  , 0.01356821, 0.01577891, 0.01071483, 0.00917972,
#        0.01178017, 0.11352477])

# %%
# mapping feature names to scores

feature_importance = {feature: importance for (feature, importance) in zip(df_train.drop('target', axis=1).columns, forest.feature_importances_)}

# %%
# sorting in descending order

feature_importance = sorted(feature_importance, key=lambda x: feature_importance[x], reverse=True)

# %%
feature_importance
# Out:
# ['Organism',
#  'Allele',
#  'kf4',
#  'Epitope Start',
#  'hydropathy',
#  'hydrophobicity_score',
#  'polarity',
#  'strength',
#  'rim',
#  'mjenergy',
#  'kf7',
#  'kf6',
#  'surface',
#  'kf10',
#  'kf8',
#  'beta',
#  'kf5',
#  'turn',
#  'kf9',
#  'core',
#  'kf3',
#  'alpha',
#  'kf1',
#  'kf2',
#  'disorder',
#  'kidera_score',
#  'volume',
#  'aa_score',
#  'pH',
#  'charge',
#  'Length',
#  'count']

# %%
# lets try to remove some of the most important features

forest_wo_important = RandomForestClassifier(n_estimators = 350, max_depth = 15, max_features = 'sqrt', 
                                             bootstrap = 'True', n_jobs = -1, oob_score=True, min_samples_leaf=5, 
                                             min_samples_split=5, random_state=6)

# %%
# top 5 features are removed

X_train_i, X_test_i, y_train_i, y_test_i = train_test_split(df_train.drop(feature_importance[:5] + ['target'], axis=1), df_train.target, test_size=0.3, 
                                                    stratify=df_train.target, shuffle=True)

# %%
forest_wo_important.fit(X_train_i, y_train_i)
# Out:
# RandomForestClassifier(bootstrap='True', class_weight=None, criterion='gini',
#                        max_depth=15, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=350,
#                        n_jobs=-1, oob_score=True, random_state=6, verbose=0,
#                        warm_start=False)

# %%
# still quite good

forest_wo_important.oob_score_
# Out:
# 0.7456189937817976

# %%
# no overfitting detected

forest_wo_important.feature_importances_
# Out:
# array([0.01202506, 0.02683709, 0.02877052, 0.08410198, 0.02794068,
#        0.03901103, 0.01113782, 0.02890833, 0.02049243, 0.05874414,
#        0.07072346, 0.04465372, 0.03382333, 0.02929276, 0.01114926,
#        0.06772776, 0.02525673, 0.07016687, 0.02972304, 0.03004028,
#        0.03124549, 0.03111086, 0.04020222, 0.04117063, 0.03855207,
#        0.03002537, 0.03716706])

# %%
# just checking correlations

df_train.corr().loc['target'].sort_values()
# Out:
# kf4                    -0.444057
# polarity               -0.407254
# rim                    -0.344731
# mjenergy               -0.320355
# disorder               -0.298251
# surface                -0.284620
# turn                   -0.181708
# aa_score               -0.128705
# alpha                  -0.128705
# Length                 -0.122908
# count                  -0.122908
# kf2                    -0.106454
# Allele                 -0.105212
# kf6                    -0.098253
# volume                 -0.095211
# kf8                    -0.092800
# pH                     -0.040037
# core                   -0.030844
# kf5                    -0.024727
# kidera_score           -0.002094
# kf1                    -0.002094
# charge                  0.021734
# beta                    0.032279
# kf3                     0.093755
# kf9                     0.104520
# kf7                     0.135719
# kf10                    0.137432
# Epitope Start           0.146241
# Organism                0.289148
# strength                0.378742
# hydrophobicity_score    0.403977
# hydropathy              0.403977
# target                  1.000000
# Name: target, dtype: float64

# %%
# need to choose features to use 

# dendrogram = sch.dendrogram(sch.linkage(X_train, method='ward'))

# %%
# distributions
# see data/scatter.jpg

sm = scatter_matrix(df_train, alpha = 0.2, figsize = (50, 50), diagonal = 'kde')

# %%
# distributions by target
# see data/target coloured.png

shape = len(df_train.columns)
k = 1
fig = plt.figure(figsize=(120, 120))
for i, feature_1 in enumerate(df_train.columns):
    for j, feature_2 in enumerate(df_train.columns):
        plt.subplot(shape, shape, k)
        plt.scatter(df_train.loc[df_train.target == 1][feature_1], df_train.loc[df_train.target == 1][feature_2], s=10, marker='o', color='red', alpha=0.05)
        plt.scatter(df_train.loc[df_train.target == 0][feature_1], df_train.loc[df_train.target == 0][feature_2], s=10, marker='o', color='blue', alpha=0.05)
#         plt.scatter(normed_res[labels==2][feature_1], normed_res[labels==2][feature_2], s=50, marker='o', color='green')
        plt.title(f'{feature_1} vs {feature_2}')
        plt.xlabel(feature_1)
        plt.ylabel(feature_2)
        k += 1
plt.tight_layout()
plt.savefig('data/target coloured.png', quality=100)

# %%
# model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
# model.fit(df_train)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=3,
#                         pooling_func='deprecated')
